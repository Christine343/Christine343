# %% [markdown]
# # My final project - Cryptocurrencies

# %%
import pandas as pd
coin = pd.read_csv(r'C:\Users\Christine.Murphy\OneDrive - Concern Worldwide\2022\UCD_Course\consolidated_coin_data.csv')

# %%
coin.head()
# Out:
#   Currency          Date    Open    High     Low   Close        Volume  \
# 0    tezos  Dec 04, 2019   1.29    1.32    1.25    1.25    46,048,752
# 1    tezos  Dec 03, 2019   1.24    1.32    1.21    1.29    41,462,224
# 2    tezos  Dec 02, 2019   1.25    1.26    1.20    1.24    27,574,097
# 3    tezos  Dec 01, 2019   1.33    1.34    1.25    1.25    24,127,567
# 4    tezos  Nov 30, 2019   1.31    1.37    1.31    1.33    28,706,667
#
#       Market Cap
# 0   824,588,509
# 1   853,213,342
# 2   817,872,179
# 3   828,296,390
# 4   879,181,680

# %%
coin.dtypes
# Out:
# Currency      object
# Date          object
# Open          object
# High          object
# Low           object
# Close         object
# Volume        object
# Market Cap    object
# dtype: object

# %% [markdown]
# Columns from Open to Market cap are objects - need to remove comma and convert to floats

# %%
coin['Open'] = coin['Open'].str.replace(r'\W',"").astype(float)
print(coin)
# Out:
#          Currency          Date   Open    High     Low   Close        Volume  \
# 0           tezos  Dec 04, 2019  129.0   1.32    1.25    1.25    46,048,752
# 1           tezos  Dec 03, 2019  124.0   1.32    1.21    1.29    41,462,224
# 2           tezos  Dec 02, 2019  125.0   1.26    1.20    1.24    27,574,097
# 3           tezos  Dec 01, 2019  133.0   1.34    1.25    1.25    24,127,567
# 4           tezos  Nov 30, 2019  131.0   1.37    1.31    1.33    28,706,667
# ...           ...           ...    ...     ...     ...     ...           ...
# 28939  bitcoin-sv  May 02, 2013  378.0   4.04    3.01    3.37           -
# 28940  bitcoin-sv  May 01, 2013  429.0   4.36    3.52    3.80           -
# 28941  bitcoin-sv  Apr 30, 2013  440.0   4.57    4.17    4.30           -
# 28942  bitcoin-sv  Apr 29, 2013  437.0   4.57    4.23    4.38           -
# 28943  bitcoin-sv  Apr 28, 2013  430.0   4.40    4.18    4.35           -
#
#           Market Cap
# 0       824,588,509
# 1       853,213,342
# ...

# %%
coin['High'] = coin['High'].str.replace(r'\W',"").astype(float)
print(coin)
# Out:
#          Currency          Date   Open   High     Low   Close        Volume  \
# 0           tezos  Dec 04, 2019  129.0  132.0   1.25    1.25    46,048,752
# 1           tezos  Dec 03, 2019  124.0  132.0   1.21    1.29    41,462,224
# 2           tezos  Dec 02, 2019  125.0  126.0   1.20    1.24    27,574,097
# 3           tezos  Dec 01, 2019  133.0  134.0   1.25    1.25    24,127,567
# 4           tezos  Nov 30, 2019  131.0  137.0   1.31    1.33    28,706,667
# ...           ...           ...    ...    ...     ...     ...           ...
# 28939  bitcoin-sv  May 02, 2013  378.0  404.0   3.01    3.37           -
# 28940  bitcoin-sv  May 01, 2013  429.0  436.0   3.52    3.80           -
# 28941  bitcoin-sv  Apr 30, 2013  440.0  457.0   4.17    4.30           -
# 28942  bitcoin-sv  Apr 29, 2013  437.0  457.0   4.23    4.38           -
# 28943  bitcoin-sv  Apr 28, 2013  430.0  440.0   4.18    4.35           -
#
#           Market Cap
# 0       824,588,509
# 1       853,213,342
# ...

# %%
coin.dtypes
# Out:
# Currency       object
# Date           object
# Open          float64
# High          float64
# Low            object
# Close          object
# Volume         object
# Market Cap     object
# dtype: object

# %% [markdown]
# Just checked if the strings have changed to floats for High and Low - will continue for Low, and close

# %%
coin['Low'] = coin['Low'].str.replace(r'\W',"").astype(float)
# Out:
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_2464/2435108886.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['Low'] = coin['Low'].str.replace(r'\W',"").astype(float)

# %%
coin['Close'] = coin['Close'].str.replace(r'\W',"").astype(float)
# Out:
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_2464/2296899651.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['Close'] = coin['Close'].str.replace(r'\W',"").astype(float)

# %%
coin.dtypes
# Out:
# Currency       object
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume         object
# Market Cap     object
# dtype: object

# %%
coin.head()
# Out:
#   Currency          Date   Open   High    Low  Close        Volume  \
# 0    tezos  Dec 04, 2019  129.0  132.0  125.0  125.0   46,048,752
# 1    tezos  Dec 03, 2019  124.0  132.0  121.0  129.0   41,462,224
# 2    tezos  Dec 02, 2019  125.0  126.0  120.0  124.0   27,574,097
# 3    tezos  Dec 01, 2019  133.0  134.0  125.0  125.0   24,127,567
# 4    tezos  Nov 30, 2019  131.0  137.0  131.0  133.0   28,706,667
#
#       Market Cap
# 0   824,588,509
# 1   853,213,342
# 2   817,872,179
# 3   828,296,390
# 4   879,181,680

# %% [markdown]
# # Exploring my Coin data, cleaning and analysis

# %%
coin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28944 entries, 0 to 28943
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Currency    28944 non-null  object
#  1   Date        28944 non-null  object
#  2   Open        28944 non-null  float64
#  3   High        28944 non-null  float64
#  4   Low         28944 non-null  float64
#  5   Close       28944 non-null  float64
#  6   Volume      28944 non-null  object
#  7   Market Cap  28944 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 1.8+ MB

# %%
coin.describe()
# Out:
#                Open          High           Low         Close
# count  2.894400e+04  2.894400e+04  2.894400e+04  2.894400e+04
# mean   3.007197e+04  3.098328e+04  2.908584e+04  3.009474e+04
# std    1.373885e+05  1.416599e+05  1.325073e+05  1.374461e+05
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.100000e+01  2.100000e+01  2.000000e+01  2.100000e+01
# 50%    2.995000e+02  3.090000e+02  2.880000e+02  2.980000e+02
# 75%    2.443000e+03  2.553000e+03  2.327000e+03  2.443000e+03
# max    1.947580e+06  2.008900e+06  1.897410e+06  1.949740e+06

# %%
coin.dtypes
# Out:
# Currency       object
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume         object
# Market Cap     object
# dtype: object

# %%
coin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28944 entries, 0 to 28943
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Currency    28944 non-null  object
#  1   Date        28944 non-null  object
#  2   Open        28944 non-null  float64
#  3   High        28944 non-null  float64
#  4   Low         28944 non-null  float64
#  5   Close       28944 non-null  float64
#  6   Volume      28944 non-null  object
#  7   Market Cap  28944 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 1.8+ MB

# %%
coin.mean()
# Out:
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_2464/3054436936.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   coin.mean()
# Open     30071.974779
# High     30983.280818
# Low      29085.837237
# Close    30094.736249
# dtype: float64

# %%
import seaborn as sns

# %%
import numpy as np
import seaborn as sns

# %%
for index, row in coin.head(2).iterrows():
    print(index)
    print(row)
# Out:
# 0
# Currency              tezos
# Date           Dec 04, 2019
# Open                  129.0
# High                  132.0
# Low                   125.0
# Close                 125.0
# Volume          46,048,752
# Market Cap     824,588,509
# Name: 0, dtype: object
# 1
# Currency              tezos
# Date           Dec 03, 2019
# Open                  124.0
# High                  132.0
# Low                   121.0
# Close                 129.0
# Volume          41,462,224
# Market Cap     853,213,342
# Name: 1, dtype: object

# %%
for index, row in coin.head(10).iterrows():
    print(index)
    print(row)
# Out:
# 0
# Currency              tezos
# Date           Dec 04, 2019
# Open                  129.0
# High                  132.0
# Low                   125.0
# Close                 125.0
# Volume          46,048,752
# Market Cap     824,588,509
# Name: 0, dtype: object
# 1
# Currency              tezos
# Date           Dec 03, 2019
# Open                  124.0
# High                  132.0
# Low                   121.0
# Close                 129.0
# Volume          41,462,224
# Market Cap     853,213,342
# Name: 1, dtype: object
# 2
# Currency              tezos
# Date           Dec 02, 2019
# Open                  125.0
# High                  126.0
# Low                   120.0
# Close                 124.0
# Volume          27,574,097
# Market Cap     817,872,179
# Name: 2, dtype: object
# 3
# Currency              tezos
# Date           Dec 01, 2019
# Open                  133.0
# High                  134.0
# Low                   125.0
# Close                 125.0
# ...

# %%
for index, row in coin.head().iterrows():
    print(f"{row[4]} high of {row[3]}")
# Out:
# 125.0 high of 132.0
# 121.0 high of 132.0
# 120.0 high of 126.0
# 125.0 high of 134.0
# 131.0 high of 137.0

# %%
coin.head()
# Out:
#   Currency          Date   Open   High    Low  Close        Volume  \
# 0    tezos  Dec 04, 2019  129.0  132.0  125.0  125.0   46,048,752
# 1    tezos  Dec 03, 2019  124.0  132.0  121.0  129.0   41,462,224
# 2    tezos  Dec 02, 2019  125.0  126.0  120.0  124.0   27,574,097
# 3    tezos  Dec 01, 2019  133.0  134.0  125.0  125.0   24,127,567
# 4    tezos  Nov 30, 2019  131.0  137.0  131.0  133.0   28,706,667
#
#       Market Cap
# 0   824,588,509
# 1   853,213,342
# 2   817,872,179
# 3   828,296,390
# 4   879,181,680

# %%
coin.dtypes
# Out:
# Currency       object
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume         object
# Market Cap     object
# dtype: object

# %%
coin[coin['Open']>700000].head(100)
# Out:
#      Currency          Date       Open       High        Low      Close  \
# 7236  bitcoin  Dec 04, 2019   732013.0   753978.0   717092.0   725203.0
# 7237  bitcoin  Dec 03, 2019   732398.0   741886.0   722936.0   732015.0
# 7238  bitcoin  Dec 02, 2019   742404.0   747482.0   723340.0   732199.0
# 7239  bitcoin  Dec 01, 2019   757162.0   757162.0   729134.0   742429.0
# 7240  bitcoin  Nov 30, 2019   776406.0   783610.0   751585.0   756963.0
# ...       ...           ...        ...        ...        ...        ...
# 7331  bitcoin  Aug 31, 2019   959754.0   967322.0   953180.0   963066.0
# 7332  bitcoin  Aug 30, 2019   951484.0   965612.0   942830.0   959817.0
# 7333  bitcoin  Aug 29, 2019   975679.0   975679.0   942163.0   951020.0
# 7334  bitcoin  Aug 28, 2019  1020343.0  1027937.0   971666.0   975442.0
# 7335  bitcoin  Aug 27, 2019  1037283.0  1038133.0  1008730.0  1018550.0
#
#                 Volume         Market Cap
# 7236   21,664,240,918    131,143,000,000
# ...

# %% [markdown]
# Looking at this data - prices are in cents - price for Bitcoin on Nov 18, 2019 is $8,573.98, price from this data is in cents 857,398.00

# %%
coin[coin['Open']>1900000].head(100)
# Out:
#      Currency          Date       Open       High        Low      Close  \
# 7951  bitcoin  Dec 19, 2017  1911830.0  1917780.0  1727540.0  1777670.0
# 7952  bitcoin  Dec 18, 2017  1910640.0  1937100.0  1835590.0  1911420.0
# 7953  bitcoin  Dec 17, 2017  1947580.0  2008900.0  1897410.0  1914080.0
#
#                 Volume         Market Cap
# 7951   16,894,499,840    297,801,000,000
# 7952   14,839,499,776    320,174,000,000
# 7953   13,314,599,936    320,577,000,000

# %%
coin['Currency'].value_counts()
# Out:
# tezos           2412
# binance-coin    2412
# eos             2412
# bitcoin         2412
# tether          2412
# xrp             2412
# bitcoin-cash    2412
# stellar         2412
# litecoin        2412
# ethereum        2412
# cardano         2412
# bitcoin-sv      2412
# Name: Currency, dtype: int64

# %%
ethereum = coin[coin['Currency']=='ethereum']
ethereum
# Out:
#        Currency          Date     Open     High      Low    Close  \
# 21708  ethereum  Dec 04, 2019  14792.0  15068.0  14500.0  14675.0
# 21709  ethereum  Dec 03, 2019  14906.0  15031.0  14600.0  14796.0
# 21710  ethereum  Dec 02, 2019  15118.0  15212.0  14761.0  14906.0
# 21711  ethereum  Dec 01, 2019  15249.0  15249.0  14707.0  15119.0
# 21712  ethereum  Nov 30, 2019  15529.0  15669.0  15123.0  15254.0
# ...         ...           ...      ...      ...      ...      ...
# 24115  ethereum  May 02, 2013  11638.0  12560.0   9228.0  10521.0
# 24116  ethereum  May 01, 2013  13900.0  13989.0  10772.0  11699.0
# 24117  ethereum  Apr 30, 2013  14400.0  14693.0  13405.0  13900.0
# 24118  ethereum  Apr 29, 2013  13444.0  14749.0  13400.0  14454.0
# 24119  ethereum  Apr 28, 2013  13530.0  13598.0  13210.0  13421.0
#
#                 Volume        Market Cap
# 21708   7,865,937,094    15,966,157,442
# 21709   6,204,379,850    16,095,928,402
# 21710   6,670,561,362    16,214,125,032
# ...

# %% [markdown]
# Looking at specifically ethereum above - created a subset of this data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
coin['Date'] = pd.to_datetime(coin['Date'])

# %%
coin.head()
# Out:
#   Currency       Date   Open   High    Low  Close        Volume     Market Cap
# 0    tezos 2019-12-04  129.0  132.0  125.0  125.0   46,048,752    824,588,509
# 1    tezos 2019-12-03  124.0  132.0  121.0  129.0   41,462,224    853,213,342
# 2    tezos 2019-12-02  125.0  126.0  120.0  124.0   27,574,097    817,872,179
# 3    tezos 2019-12-01  133.0  134.0  125.0  125.0   24,127,567    828,296,390
# 4    tezos 2019-11-30  131.0  137.0  131.0  133.0   28,706,667    879,181,680

# %% [markdown]
# Changed the date format to make it easier to read - year first, month and day

# %%
coin.set_index('Open', inplace=True)

# %%
coin.head()
# Out:
#       Currency   High    Low  Close        Volume     Market Cap
# Open
# 129.0    tezos  132.0  125.0  125.0   46,048,752    824,588,509
# 124.0    tezos  132.0  121.0  129.0   41,462,224    853,213,342
# 125.0    tezos  126.0  120.0  124.0   27,574,097    817,872,179
# 133.0    tezos  134.0  125.0  125.0   24,127,567    828,296,390
# 131.0    tezos  137.0  131.0  133.0   28,706,667    879,181,680

# %%
coin.set_index('Currency')
# Out:
#              High    Low  Close        Volume     Market Cap
# Currency
# tezos       132.0  125.0  125.0   46,048,752    824,588,509
# tezos       132.0  121.0  129.0   41,462,224    853,213,342
# tezos       126.0  120.0  124.0   27,574,097    817,872,179
# tezos       134.0  125.0  125.0   24,127,567    828,296,390
# tezos       137.0  131.0  133.0   28,706,667    879,181,680
# ...           ...    ...    ...           ...            ...
# bitcoin-sv  404.0  301.0  337.0          -       58,287,979
# bitcoin-sv  436.0  352.0  380.0          -       65,604,596
# bitcoin-sv  457.0  417.0  430.0          -       74,020,918
# bitcoin-sv  457.0  423.0  438.0          -       75,388,964
# bitcoin-sv  440.0  418.0  435.0          -       74,636,938
#
# [28944 rows x 5 columns]

# %%
import numpy as np

# %%
print(coin.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28944 entries, 0 to 28943
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Currency    28944 non-null  object
#  1   Date        28944 non-null  datetime64[ns]
#  2   Open        28944 non-null  float64
#  3   High        28944 non-null  float64
#  4   Low         28944 non-null  float64
#  5   Close       28944 non-null  float64
#  6   Volume      28944 non-null  object
#  7   Market Cap  28944 non-null  object
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 1.8+ MB
# None

# %%
coin['Low'] = coin['Low'].str.replace(r'\W',"").astype(float)
# Out:
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_7908/2435108886.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['Low'] = coin['Low'].str.replace(r'\W',"").astype(float)

# %%
coin['High'] = coin['High'].str.replace(r'\W',"").astype(float)
# Out:
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_7908/1775250900.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['High'] = coin['High'].str.replace(r'\W',"").astype(float)

# %%
coin['Close'] = coin['Close'].str.replace(r'\W',"").astype(float)
# Out:
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_7908/2296899651.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['Close'] = coin['Close'].str.replace(r'\W',"").astype(float)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
coin['Open'] = coin['Open'].str.replace(r'\W',"").astype(float)
# Out:
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_7908/47711041.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['Open'] = coin['Open'].str.replace(r'\W',"").astype(float)

# %%
print(coin.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28944 entries, 0 to 28943
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Currency    28944 non-null  object
#  1   Date        28944 non-null  object
#  2   Open        28944 non-null  float64
#  3   High        28944 non-null  float64
#  4   Low         28944 non-null  float64
#  5   Close       28944 non-null  float64
#  6   Volume      28944 non-null  object
#  7   Market Cap  28944 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 1.8+ MB
# None

# %%
import pandas as pd
coin = pd.read_csv(r'C:\Users\Christine.Murphy\OneDrive - Concern Worldwide\2022\UCD_Course\consolidated_coin_data.csv')

# %%
coin['Date'] = pd.to_datetime(coin['Date'])

# %%
print(coin.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28944 entries, 0 to 28943
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Currency    28944 non-null  object
#  1   Date        28944 non-null  datetime64[ns]
#  2   Open        28944 non-null  object
#  3   High        28944 non-null  object
#  4   Low         28944 non-null  object
#  5   Close       28944 non-null  object
#  6   Volume      28944 non-null  object
#  7   Market Cap  28944 non-null  object
# dtypes: datetime64[ns](1), object(7)
# memory usage: 1.8+ MB
# None

# %%
coin['Low'] = coin['Low'].str.replace(r'\W',"").astype(float)
# Out:
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_14792/2435108886.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['Low'] = coin['Low'].str.replace(r'\W',"").astype(float)

# %%
coin['High'] = coin['High'].str.replace(r'\W',"").astype(float)
# Out:
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_14792/1775250900.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['High'] = coin['High'].str.replace(r'\W',"").astype(float)

# %%
coin['Open'] = coin['Open'].str.replace(r'\W',"").astype(float)
# Out:
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_14792/47711041.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['Open'] = coin['Open'].str.replace(r'\W',"").astype(float)

# %%
coin['Close'] = coin['Close'].str.replace(r'\W',"").astype(float)
# Out:
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_14792/2296899651.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['Close'] = coin['Close'].str.replace(r'\W',"").astype(float)

# %%
coin['Date'] = coin.index

# %%
coin.dtypes
# Out:
# Currency       object
# Date            int64
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume         object
# Market Cap     object
# dtype: object

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
coin['Date'] = pd.to_datetime(coin['Date'])

# %%
coin.dtypes
# Out:
# Currency              object
# Date          datetime64[ns]
# Open                 float64
# High                 float64
# Low                  float64
# Close                float64
# Volume                object
# Market Cap            object
# dtype: object

# %%
import pandas as pd
coin = pd.read_csv(r'C:\Users\Christine.Murphy\OneDrive - Concern Worldwide\2022\UCD_Course\consolidated_coin_data.csv')

# %%
coin['Close'] = coin['Close'].str.replace(r'\W',"").astype(float)
coin['Open'] = coin['Open'].str.replace(r'\W',"").astype(float)
coin['High'] = coin['High'].str.replace(r'\W',"").astype(float)
coin['Low'] = coin['Low'].str.replace(r'\W',"").astype(float)
# Out:
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_14792/1023895653.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['Close'] = coin['Close'].str.replace(r'\W',"").astype(float)
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_14792/1023895653.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['Open'] = coin['Open'].str.replace(r'\W',"").astype(float)
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_14792/1023895653.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['High'] = coin['High'].str.replace(r'\W',"").astype(float)
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_14792/1023895653.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['Low'] = coin['Low'].str.replace(r'\W',"").astype(float)

# %%
plt.subplots(figsize=(16,8))

plt.plot(coin['Currency'],coin['High'])
plt.plot(coin['Currency'],coin['High'])

plt.xlabel('Coin type')
plt.ylabel('High value')
plt.title('Coin data')
# Out:
# Text(0.5, 1.0, 'Coin data')

# %%
sorted_coins = coin.sort_values(by=['High'], ascending=False)
print(sorted_coins.head(20))
# Out:
#      Currency          Date       Open       High        Low      Close  \
# 7953  bitcoin  Dec 17, 2017  1947580.0  2008900.0  1897410.0  1914080.0
# 7954  bitcoin  Dec 16, 2017  1776030.0  1971670.0  1751530.0  1949740.0
# 7952  bitcoin  Dec 18, 2017  1910640.0  1937100.0  1835590.0  1911420.0
# 7951  bitcoin  Dec 19, 2017  1911830.0  1917780.0  1727540.0  1777670.0
# 7962  bitcoin  Dec 08, 2017  1780290.0  1835340.0  1433690.0  1656940.0
# 7955  bitcoin  Dec 15, 2017  1660130.0  1815410.0  1660130.0  1770690.0
# 7950  bitcoin  Dec 20, 2017  1776030.0  1793470.0  1607770.0  1662460.0
# 7963  bitcoin  Dec 07, 2017  1426610.0  1789970.0  1405730.0  1789970.0
# 7958  bitcoin  Dec 12, 2017  1691980.0  1778180.0  1657160.0  1741540.0
# 7933  bitcoin  Jan 06, 2018  1746210.0  1771240.0  1676460.0  1752700.0
# 7934  bitcoin  Jan 05, 2018  1547720.0  1770520.0  1520280.0  1742950.0
# 7957  bitcoin  Dec 13, 2017  1750000.0  1765310.0  1603970.0  1640820.0
# ...

# %%
sorted_coins = coin.sort_values(by=['difference between open and close'], ascending=False)
print(sorted_coins.head(5))
# Out:
#      Currency                          Date       Open       High        Low  \
# 7923  bitcoin 1970-01-01 00:00:00.000007923  1383610.0  1384310.0  1019490.0
# 7948  bitcoin 1970-01-01 00:00:00.000007948  1589800.0  1594340.0  1183300.0
# 7396  bitcoin 1970-01-01 00:00:00.000007396  1301712.0  1331114.0  1049185.0
# 7940  bitcoin 1970-01-01 00:00:00.000007940  1468190.0  1468190.0  1235010.0
# 7928  bitcoin 1970-01-01 00:00:00.000007928  1496820.0  1501880.0  1310590.0
#
#           Close            Volume         Market Cap  \
# 7923  1149050.0   18,853,799,936    193,121,000,000
# 7948  1383180.0   22,197,999,616    231,788,000,000
# 7396  1118281.0   39,977,475,223    198,879,000,000
# 7940  1295220.0   14,452,599,808    217,240,000,000
# 7928  1340580.0   16,534,099,968    225,179,000,000
#
#       difference between open and close  percentage change
# 7923                           234560.0           0.204134
# 7948                           206620.0           0.149380
# ...

# %%
ethereum = coin[coin['Currency']=='ethereum']
ethereum
# Out:
#        Currency          Date     Open     High      Low    Close  \
# 21708  ethereum  Dec 04, 2019  14792.0  15068.0  14500.0  14675.0
# 21709  ethereum  Dec 03, 2019  14906.0  15031.0  14600.0  14796.0
# 21710  ethereum  Dec 02, 2019  15118.0  15212.0  14761.0  14906.0
# 21711  ethereum  Dec 01, 2019  15249.0  15249.0  14707.0  15119.0
# 21712  ethereum  Nov 30, 2019  15529.0  15669.0  15123.0  15254.0
# ...         ...           ...      ...      ...      ...      ...
# 24115  ethereum  May 02, 2013  11638.0  12560.0   9228.0  10521.0
# 24116  ethereum  May 01, 2013  13900.0  13989.0  10772.0  11699.0
# 24117  ethereum  Apr 30, 2013  14400.0  14693.0  13405.0  13900.0
# 24118  ethereum  Apr 29, 2013  13444.0  14749.0  13400.0  14454.0
# 24119  ethereum  Apr 28, 2013  13530.0  13598.0  13210.0  13421.0
#
#                 Volume        Market Cap
# 21708   7,865,937,094    15,966,157,442
# 21709   6,204,379,850    16,095,928,402
# 21710   6,670,561,362    16,214,125,032
# ...

# %%
sorted_coins = ethereum.sort_values(by=['High'], ascending=False)
print(sorted_coins.head(20))
# Out:
#        Currency          Date      Open      High       Low     Close  \
# 22398  ethereum  Jan 13, 2018  127047.0  143288.0  127047.0  139642.0
# 22401  ethereum  Jan 10, 2018  130034.0  141738.0  122660.0  125582.0
# 22397  ethereum  Jan 14, 2018  139748.0  140056.0  128621.0  136677.0
# 22396  ethereum  Jan 15, 2018  136521.0  139059.0  129060.0  129192.0
# 22400  ethereum  Jan 11, 2018  126809.0  133730.0  113517.0  115493.0
# 22402  ethereum  Jan 09, 2018  114600.0  132098.0  114549.0  129974.0
# 22399  ethereum  Jan 12, 2018  115829.0  129604.0  112009.0  127320.0
# 22395  ethereum  Jan 16, 2018  129263.0  129263.0   87554.0  105369.0
# 22403  ethereum  Jan 08, 2018  115826.0  126693.0  101605.0  114853.0
# 22383  ethereum  Jan 28, 2018  111178.0  125777.0  111178.0  124601.0
# 22382  ethereum  Jan 29, 2018  124670.0  125670.0  116908.0  118236.0
# 22381  ethereum  Jan 30, 2018  118413.0  118463.0  105897.0  107113.0
# ...

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Date',y='difference between open and close', data=ethereum, hue='Currency')
plt.title('Crypto data Ethereum only')
# Out:
# Text(0.5, 1.0, 'Crypto data Ethereum only')

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Low',y='High', data=coin, hue='Currency')
plt.title('Crypto data by Coin')
# Out:
# Text(0.5, 1.0, 'Crypto data by Coin')

# %%
sorted_coins = coin.sort_values(by=['High'], ascending=False)
print(sorted_coins.head(10))
# Out:
#      Currency          Date       Open       High        Low      Close  \
# 7953  bitcoin  Dec 17, 2017  1947580.0  2008900.0  1897410.0  1914080.0
# 7954  bitcoin  Dec 16, 2017  1776030.0  1971670.0  1751530.0  1949740.0
# 7952  bitcoin  Dec 18, 2017  1910640.0  1937100.0  1835590.0  1911420.0
# 7951  bitcoin  Dec 19, 2017  1911830.0  1917780.0  1727540.0  1777670.0
# 7962  bitcoin  Dec 08, 2017  1780290.0  1835340.0  1433690.0  1656940.0
# 7955  bitcoin  Dec 15, 2017  1660130.0  1815410.0  1660130.0  1770690.0
# 7950  bitcoin  Dec 20, 2017  1776030.0  1793470.0  1607770.0  1662460.0
# 7963  bitcoin  Dec 07, 2017  1426610.0  1789970.0  1405730.0  1789970.0
# 7958  bitcoin  Dec 12, 2017  1691980.0  1778180.0  1657160.0  1741540.0
# 7933  bitcoin  Jan 06, 2018  1746210.0  1771240.0  1676460.0  1752700.0
#
#                 Volume         Market Cap  difference between open and close
# 7953   13,314,599,936    320,577,000,000                             33500.0
# ...

# %%
coin.groupby('Date')
coin.head(10)
# Out:
#   Currency          Date   Open   High    Low  Close        Volume  \
# 0    tezos  Dec 04, 2019  129.0  132.0  125.0  125.0   46,048,752
# 1    tezos  Dec 03, 2019  124.0  132.0  121.0  129.0   41,462,224
# 2    tezos  Dec 02, 2019  125.0  126.0  120.0  124.0   27,574,097
# 3    tezos  Dec 01, 2019  133.0  134.0  125.0  125.0   24,127,567
# 4    tezos  Nov 30, 2019  131.0  137.0  131.0  133.0   28,706,667
# 5    tezos  Nov 29, 2019  128.0  134.0  128.0  131.0   32,270,224
# 6    tezos  Nov 28, 2019  126.0  135.0  122.0  128.0   44,240,281
# 7    tezos  Nov 27, 2019  124.0  127.0  116.0  126.0   47,723,271
# 8    tezos  Nov 26, 2019  124.0  128.0  123.0  124.0   54,828,808
# 9    tezos  Nov 25, 2019  133.0  133.0  121.0  124.0   64,954,006
#
#       Market Cap  difference between open and close  percentage change
# 0   824,588,509                                 4.0           0.032000
# 1   853,213,342                                -5.0          -0.038760
# ...

# %%
sorted_coins = ethereum.sort_values(by=['High'], ascending=False)
print(sorted_coins.head(10))
# Out:
#        Currency          Date      Open      High       Low     Close  \
# 22398  ethereum  Jan 13, 2018  127047.0  143288.0  127047.0  139642.0
# 22401  ethereum  Jan 10, 2018  130034.0  141738.0  122660.0  125582.0
# 22397  ethereum  Jan 14, 2018  139748.0  140056.0  128621.0  136677.0
# 22396  ethereum  Jan 15, 2018  136521.0  139059.0  129060.0  129192.0
# 22400  ethereum  Jan 11, 2018  126809.0  133730.0  113517.0  115493.0
# 22402  ethereum  Jan 09, 2018  114600.0  132098.0  114549.0  129974.0
# 22399  ethereum  Jan 12, 2018  115829.0  129604.0  112009.0  127320.0
# 22395  ethereum  Jan 16, 2018  129263.0  129263.0   87554.0  105369.0
# 22403  ethereum  Jan 08, 2018  115826.0  126693.0  101605.0  114853.0
# 22383  ethereum  Jan 28, 2018  111178.0  125777.0  111178.0  124601.0
#
#                 Volume         Market Cap
# 22398   5,746,760,192    135,401,000,000
# 22401   9,214,950,400    121,689,000,000
# 22397   4,841,630,208    132,555,000,000
# ...

# %%
sorted_coins = ethereum.sort_values(by=['Low'], ascending=True)
print(sorted_coins.head(10))
# Out:
#        Currency          Date  Open  High   Low  Close     Volume  \
# 23213  ethereum  Oct 21, 2015  43.0  48.0  42.0   45.0   609,085
# 23212  ethereum  Oct 22, 2015  44.0  62.0  42.0   57.0   924,822
# 23214  ethereum  Oct 20, 2015  49.0  50.0  43.0   43.0   383,921
# 23215  ethereum  Oct 19, 2015  52.0  52.0  48.0   49.0   243,742
# 23220  ethereum  Oct 14, 2015  61.0  61.0  48.0   52.0   971,664
# 23211  ethereum  Oct 23, 2015  57.0  61.0  50.0   54.0   878,822
# 23216  ethereum  Oct 18, 2015  55.0  55.0  51.0   52.0   133,690
# 23219  ethereum  Oct 15, 2015  52.0  57.0  51.0   56.0   371,022
# 23218  ethereum  Oct 16, 2015  56.0  57.0  52.0   54.0   249,891
# 23210  ethereum  Oct 24, 2015  54.0  58.0  52.0   56.0   258,356
#
#          Market Cap  difference between open and close
# 23213   33,150,826                                -2.0
# 23212   42,085,192                               -13.0
# 23214   32,213,626                                 6.0
# ...

# %%
coin.isnull()
# Out:
#        Currency   Date   Open   High    Low  Close  Volume  Market Cap
# 0         False  False  False  False  False  False   False       False
# 1         False  False  False  False  False  False   False       False
# 2         False  False  False  False  False  False   False       False
# 3         False  False  False  False  False  False   False       False
# 4         False  False  False  False  False  False   False       False
# ...         ...    ...    ...    ...    ...    ...     ...         ...
# 28939     False  False  False  False  False  False   False       False
# 28940     False  False  False  False  False  False   False       False
# 28941     False  False  False  False  False  False   False       False
# 28942     False  False  False  False  False  False   False       False
# 28943     False  False  False  False  False  False   False       False
#
# [28944 rows x 8 columns]

# %%
coin.head()
# Out:
#   Currency          Date   Open   High    Low  Close        Volume  \
# 0    tezos  Dec 04, 2019  129.0  132.0  125.0  125.0   46,048,752
# 1    tezos  Dec 03, 2019  124.0  132.0  121.0  129.0   41,462,224
# 2    tezos  Dec 02, 2019  125.0  126.0  120.0  124.0   27,574,097
# 3    tezos  Dec 01, 2019  133.0  134.0  125.0  125.0   24,127,567
# 4    tezos  Nov 30, 2019  131.0  137.0  131.0  133.0   28,706,667
#
#       Market Cap
# 0   824,588,509
# 1   853,213,342
# 2   817,872,179
# 3   828,296,390
# 4   879,181,680

# %%
import numpy as np
import seaborn as sns

# %%
for x in coin:
    print(x)
# Out:
# Currency
# Date
# Open
# High
# Low
# Close
# Volume
# Market Cap

# %%
coin['difference between open and close'] = coin['Open'] - coin['Close']
coin.head()
# Out:
#   Currency          Date   Open   High    Low  Close        Volume  \
# 0    tezos  Dec 04, 2019  129.0  132.0  125.0  125.0   46,048,752
# 1    tezos  Dec 03, 2019  124.0  132.0  121.0  129.0   41,462,224
# 2    tezos  Dec 02, 2019  125.0  126.0  120.0  124.0   27,574,097
# 3    tezos  Dec 01, 2019  133.0  134.0  125.0  125.0   24,127,567
# 4    tezos  Nov 30, 2019  131.0  137.0  131.0  133.0   28,706,667
#
#       Market Cap  difference between open and close
# 0   824,588,509                                 4.0
# 1   853,213,342                                -5.0
# 2   817,872,179                                 1.0
# 3   828,296,390                                 8.0
# 4   879,181,680                                -2.0

# %%
sorted_coins = coin.sort_values(by=['difference between open and close'], ascending=False)
print(sorted_coins.head(20))
# Out:
#      Currency          Date       Open       High        Low      Close  \
# 7923  bitcoin  Jan 16, 2018  1383610.0  1384310.0  1019490.0  1149050.0
# 7948  bitcoin  Dec 22, 2017  1589800.0  1594340.0  1183300.0  1383180.0
# 7396  bitcoin  Jun 27, 2019  1301712.0  1331114.0  1049185.0  1118281.0
# 7940  bitcoin  Dec 30, 2017  1468190.0  1468190.0  1235010.0  1295220.0
# 7928  bitcoin  Jan 11, 2018  1496820.0  1501880.0  1310590.0  1340580.0
# 7377  bitcoin  Jul 16, 2019  1089665.0  1099663.0   944811.0   947764.0
# 7961  bitcoin  Dec 09, 2017  1652330.0  1678300.0  1367490.0  1517820.0
# 7951  bitcoin  Dec 19, 2017  1911830.0  1917780.0  1727540.0  1777670.0
# 7903  bitcoin  Feb 05, 2018   827054.0   836484.0   675668.0   695527.0
# 7931  bitcoin  Jan 08, 2018  1647620.0  1653790.0  1420820.0  1517010.0
# 7918  bitcoin  Jan 21, 2018  1288920.0  1289590.0  1128820.0  1160010.0
# 7942  bitcoin  Dec 28, 2017  1586410.0  1588840.0  1393730.0  1460650.0
# ...

# %%
coin['percentage change'] = coin['difference between open and close'] / coin['Close']
coin.head()
# Out:
#   Currency          Date   Open   High    Low  Close        Volume  \
# 0    tezos  Dec 04, 2019  129.0  132.0  125.0  125.0   46,048,752
# 1    tezos  Dec 03, 2019  124.0  132.0  121.0  129.0   41,462,224
# 2    tezos  Dec 02, 2019  125.0  126.0  120.0  124.0   27,574,097
# 3    tezos  Dec 01, 2019  133.0  134.0  125.0  125.0   24,127,567
# 4    tezos  Nov 30, 2019  131.0  137.0  131.0  133.0   28,706,667
#
#       Market Cap  difference between open and close  percentage change
# 0   824,588,509                                 4.0           0.032000
# 1   853,213,342                                -5.0          -0.038760
# 2   817,872,179                                 1.0           0.008065
# 3   828,296,390                                 8.0           0.064000
# 4   879,181,680                                -2.0          -0.015038

# %%
import pandas as pd
coin = pd.read_csv(r'C:\Users\Christine.Murphy\OneDrive - Concern Worldwide\2022\UCD_Course\consolidated_coin_data.csv')

# %%
coin.drop_duplicates(subset=['Volume', 'Market Cap']).head(10)
# Out:
#   Currency          Date    Open    High     Low   Close        Volume  \
# 0    tezos  Dec 04, 2019   1.29    1.32    1.25    1.25    46,048,752
# 1    tezos  Dec 03, 2019   1.24    1.32    1.21    1.29    41,462,224
# 2    tezos  Dec 02, 2019   1.25    1.26    1.20    1.24    27,574,097
# 3    tezos  Dec 01, 2019   1.33    1.34    1.25    1.25    24,127,567
# 4    tezos  Nov 30, 2019   1.31    1.37    1.31    1.33    28,706,667
# 5    tezos  Nov 29, 2019   1.28    1.34    1.28    1.31    32,270,224
# 6    tezos  Nov 28, 2019   1.26    1.35    1.22    1.28    44,240,281
# 7    tezos  Nov 27, 2019   1.24    1.27    1.16    1.26    47,723,271
# 8    tezos  Nov 26, 2019   1.24    1.28    1.23    1.24    54,828,808
# 9    tezos  Nov 25, 2019   1.33    1.33    1.21    1.24    64,954,006
#
#       Market Cap
# 0   824,588,509
# 1   853,213,342
# 2   817,872,179
# 3   828,296,390
# 4   879,181,680
# 5   867,085,098
# 6   845,073,679
# 7   829,672,736
# 8   822,065,277
# 9   815,688,075

# %%
coin.isnull()
# Out:
#        Currency   Date   Open   High    Low  Close  Volume  Market Cap
# 0         False  False  False  False  False  False   False       False
# 1         False  False  False  False  False  False   False       False
# 2         False  False  False  False  False  False   False       False
# 3         False  False  False  False  False  False   False       False
# 4         False  False  False  False  False  False   False       False
# ...         ...    ...    ...    ...    ...    ...     ...         ...
# 28939     False  False  False  False  False  False   False       False
# 28940     False  False  False  False  False  False   False       False
# 28941     False  False  False  False  False  False   False       False
# 28942     False  False  False  False  False  False   False       False
# 28943     False  False  False  False  False  False   False       False
#
# [28944 rows x 8 columns]

# %%
coin.isnull().sum()
# Out:
# Currency      0
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Market Cap    0
# dtype: int64

# %%
coin.iloc[[1,10000,25000], [0,1,2,3,4,5]]
# Out:
#       Currency          Date    Open    High     Low   Close
# 1        tezos  Dec 03, 2019   1.24    1.32    1.21    1.29
# 10000   tether  Dec 17, 2018   1.01    1.02    1.00    1.01
# 25000  cardano  Jul 07, 2017   0.03    0.03    0.02    0.02

# %%
coin.iloc[[15000,10001,28000], [0,1,2,3,4,5]]
# Out:
#            Currency          Date      Open      High       Low     Close
# 15000  bitcoin-cash  Jun 24, 2018   764.62    767.02    676.94    749.36
# 10001        tether  Dec 16, 2018     1.01      1.01      1.00      1.01
# 28000    bitcoin-sv  Nov 27, 2015     3.60      3.63      3.52      3.58

# %%
coin_labelled = coin.set_index('Currency')
coin_labelled.loc[['cardano', 'bitcoin-sv']]
# Out:
#                     Date    Open    High     Low   Close        Volume  \
# Currency
# cardano     Dec 04, 2019   0.04    0.04    0.04    0.04    51,692,274
# cardano     Dec 03, 2019   0.04    0.04    0.04    0.04    34,356,883
# cardano     Dec 02, 2019   0.04    0.04    0.04    0.04    43,069,274
# cardano     Dec 01, 2019   0.04    0.04    0.04    0.04    59,641,355
# cardano     Nov 30, 2019   0.04    0.04    0.04    0.04    64,184,926
# ...                  ...     ...     ...     ...     ...           ...
# bitcoin-sv  May 02, 2013   3.78    4.04    3.01    3.37           -
# bitcoin-sv  May 01, 2013   4.29    4.36    3.52    3.80           -
# bitcoin-sv  Apr 30, 2013   4.40    4.57    4.17    4.30           -
# bitcoin-sv  Apr 29, 2013   4.37    4.57    4.23    4.38           -
# bitcoin-sv  Apr 28, 2013   4.30    4.40    4.18    4.35           -
#
#                  Market Cap
# Currency
# cardano        969,802,335
# cardano        983,080,974
# cardano        986,684,920
# ...

# %%
coin_labelled = coin.set_index('Currency')
coin_labelled.loc[['cardano', 'bitcoin-cash','tether']].head(50)
# Out:
#                   Date    Open    High     Low   Close         Volume  \
# Currency
# cardano   Dec 04, 2019   0.04    0.04    0.04    0.04     51,692,274
# cardano   Dec 03, 2019   0.04    0.04    0.04    0.04     34,356,883
# cardano   Dec 02, 2019   0.04    0.04    0.04    0.04     43,069,274
# cardano   Dec 01, 2019   0.04    0.04    0.04    0.04     59,641,355
# cardano   Nov 30, 2019   0.04    0.04    0.04    0.04     64,184,926
# cardano   Nov 29, 2019   0.04    0.04    0.04    0.04     99,506,198
# cardano   Nov 28, 2019   0.04    0.04    0.04    0.04     60,743,403
# cardano   Nov 27, 2019   0.04    0.04    0.04    0.04     76,841,561
# cardano   Nov 26, 2019   0.04    0.04    0.04    0.04     57,431,470
# cardano   Nov 25, 2019   0.04    0.04    0.03    0.04     96,694,224
# cardano   Nov 24, 2019   0.04    0.04    0.04    0.04     62,998,664
# cardano   Nov 23, 2019   0.04    0.04    0.04    0.04     58,979,321
# ...

# %%
pd.set_option('display.max_columns', None)
coin.head()
# Out:
#   Currency          Date    Open    High     Low   Close        Volume  \
# 0    tezos  Dec 04, 2019   1.29    1.32    1.25    1.25    46,048,752
# 1    tezos  Dec 03, 2019   1.24    1.32    1.21    1.29    41,462,224
# 2    tezos  Dec 02, 2019   1.25    1.26    1.20    1.24    27,574,097
# 3    tezos  Dec 01, 2019   1.33    1.34    1.25    1.25    24,127,567
# 4    tezos  Nov 30, 2019   1.31    1.37    1.31    1.33    28,706,667
#
#       Market Cap
# 0   824,588,509
# 1   853,213,342
# 2   817,872,179
# 3   828,296,390
# 4   879,181,680

# %%
coin.columns
# Out:
# Index(['Currency', 'Date', 'Open', 'High', 'Low', 'Close', 'Volume',
#        'Market Cap'],
#       dtype='object')

# %%
coin.dropna(how='all',subset=['Currency', 'Date']).shape
# Out:
# (28944, 8)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
coin.head()
# Out:
#   Currency          Date    Open    High     Low   Close        Volume  \
# 0    tezos  Dec 04, 2019   1.29    1.32    1.25    1.25    46,048,752
# 1    tezos  Dec 03, 2019   1.24    1.32    1.21    1.29    41,462,224
# 2    tezos  Dec 02, 2019   1.25    1.26    1.20    1.24    27,574,097
# 3    tezos  Dec 01, 2019   1.33    1.34    1.25    1.25    24,127,567
# 4    tezos  Nov 30, 2019   1.31    1.37    1.31    1.33    28,706,667
#
#       Market Cap
# 0   824,588,509
# 1   853,213,342
# 2   817,872,179
# 3   828,296,390
# 4   879,181,680

# %%
coin.head()
# Out:
#   Currency          Date    Open    High     Low   Close        Volume  \
# 0    tezos  Dec 04, 2019   1.29    1.32    1.25    1.25    46,048,752
# 1    tezos  Dec 03, 2019   1.24    1.32    1.21    1.29    41,462,224
# 2    tezos  Dec 02, 2019   1.25    1.26    1.20    1.24    27,574,097
# 3    tezos  Dec 01, 2019   1.33    1.34    1.25    1.25    24,127,567
# 4    tezos  Nov 30, 2019   1.31    1.37    1.31    1.33    28,706,667
#
#       Market Cap
# 0   824,588,509
# 1   853,213,342
# 2   817,872,179
# 3   828,296,390
# 4   879,181,680

# %%
coin.groupby('Currency').mean()
# Out:
# C:\Users\Christine.Murphy\Anaconda101\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Empty DataFrame
# Columns: []
# Index: [binance-coin, bitcoin, bitcoin-cash, bitcoin-sv, cardano, eos, ethereum, litecoin, stellar, tether, tezos, xrp]

# %%
coin_labelled = coin.set_index('Currency')
coin_labelled.head()
# Out:
#                Date   Open   High    Low  Close        Volume     Market Cap
# Currency
# tezos    2019-12-04  129.0  132.0  125.0  125.0   46,048,752    824,588,509
# tezos    2019-12-03  124.0  132.0  121.0  129.0   41,462,224    853,213,342
# tezos    2019-12-02  125.0  126.0  120.0  124.0   27,574,097    817,872,179
# tezos    2019-12-01  133.0  134.0  125.0  125.0   24,127,567    828,296,390
# tezos    2019-11-30  131.0  137.0  131.0  133.0   28,706,667    879,181,680

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
ethereum = coin[coin['Currency']=='ethereum']
ethereum
# Out:
#        Currency          Date      Open      High       Low     Close  \
# 21708  ethereum  Dec 04, 2019   147.92    150.68    145.00    146.75
# 21709  ethereum  Dec 03, 2019   149.06    150.31    146.00    147.96
# 21710  ethereum  Dec 02, 2019   151.18    152.12    147.61    149.06
# 21711  ethereum  Dec 01, 2019   152.49    152.49    147.07    151.19
# 21712  ethereum  Nov 30, 2019   155.29    156.69    151.23    152.54
# ...         ...           ...       ...       ...       ...       ...
# 24115  ethereum  May 02, 2013   116.38    125.60     92.28    105.21
# 24116  ethereum  May 01, 2013   139.00    139.89    107.72    116.99
# 24117  ethereum  Apr 30, 2013   144.00    146.93    134.05    139.00
# 24118  ethereum  Apr 29, 2013   134.44    147.49    134.00    144.54
# 24119  ethereum  Apr 28, 2013   135.30    135.98    132.10    134.21
#
#                 Volume        Market Cap
# 21708   7,865,937,094    15,966,157,442
# 21709   6,204,379,850    16,095,928,402
# ...

# %%
ethereum.head()
# Out:
#        Currency          Date      Open      High       Low     Close  \
# 21708  ethereum  Dec 04, 2019   147.92    150.68    145.00    146.75
# 21709  ethereum  Dec 03, 2019   149.06    150.31    146.00    147.96
# 21710  ethereum  Dec 02, 2019   151.18    152.12    147.61    149.06
# 21711  ethereum  Dec 01, 2019   152.49    152.49    147.07    151.19
# 21712  ethereum  Nov 30, 2019   155.29    156.69    151.23    152.54
#
#                 Volume        Market Cap
# 21708   7,865,937,094    15,966,157,442
# 21709   6,204,379,850    16,095,928,402
# 21710   6,670,561,362    16,214,125,032
# 21711   7,102,780,298    16,443,650,814
# 21712   6,565,950,868    16,589,132,426

# %%
ethereum.groupby('Currency').mean()
# Out:
# C:\Users\Christine.Murphy\Anaconda101\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Empty DataFrame
# Columns: []
# Index: [ethereum]

# %%
import numpy as np

# %%
print(coin.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28944 entries, 0 to 28943
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Currency    28944 non-null  object
#  1   Date        28944 non-null  object
#  2   Open        28944 non-null  object
#  3   High        28944 non-null  object
#  4   Low         28944 non-null  object
#  5   Close       28944 non-null  object
#  6   Volume      28944 non-null  object
#  7   Market Cap  28944 non-null  object
# dtypes: object(8)
# memory usage: 1.8+ MB
# None

# %%
import pandas as pd
coin = pd.read_csv(r'C:\Users\Christine.Murphy\OneDrive - Concern Worldwide\2022\UCD_Course\consolidated_coin_data.csv')

# %%
coin['Close'] = coin['Close'].str.replace(r'\W',"").astype(float)
coin['Open'] = coin['Open'].str.replace(r'\W',"").astype(float)
coin['High'] = coin['High'].str.replace(r'\W',"").astype(float)
coin['Low'] = coin['Low'].str.replace(r'\W',"").astype(float)
# Out:
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_14792/1023895653.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['Close'] = coin['Close'].str.replace(r'\W',"").astype(float)
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_14792/1023895653.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['Open'] = coin['Open'].str.replace(r'\W',"").astype(float)
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_14792/1023895653.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['High'] = coin['High'].str.replace(r'\W',"").astype(float)
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_14792/1023895653.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   coin['Low'] = coin['Low'].str.replace(r'\W',"").astype(float)

# %%
coin.dtypes
# Out:
# Currency       object
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume         object
# Market Cap     object
# dtype: object

# %%
ethereum = coin[coin['Currency']=='ethereum']
ethereum
# Out:
#        Currency          Date     Open     High      Low    Close  \
# 21708  ethereum  Dec 04, 2019  14792.0  15068.0  14500.0  14675.0
# 21709  ethereum  Dec 03, 2019  14906.0  15031.0  14600.0  14796.0
# 21710  ethereum  Dec 02, 2019  15118.0  15212.0  14761.0  14906.0
# 21711  ethereum  Dec 01, 2019  15249.0  15249.0  14707.0  15119.0
# 21712  ethereum  Nov 30, 2019  15529.0  15669.0  15123.0  15254.0
# ...         ...           ...      ...      ...      ...      ...
# 24115  ethereum  May 02, 2013  11638.0  12560.0   9228.0  10521.0
# 24116  ethereum  May 01, 2013  13900.0  13989.0  10772.0  11699.0
# 24117  ethereum  Apr 30, 2013  14400.0  14693.0  13405.0  13900.0
# 24118  ethereum  Apr 29, 2013  13444.0  14749.0  13400.0  14454.0
# 24119  ethereum  Apr 28, 2013  13530.0  13598.0  13210.0  13421.0
#
#                 Volume        Market Cap
# 21708   7,865,937,094    15,966,157,442
# 21709   6,204,379,850    16,095,928,402
# 21710   6,670,561,362    16,214,125,032
# ...

# %%
xrp= coin[coin['Currency']=='xrp']
xrp
# Out:
#       Currency          Date     Open     High      Low    Close  \
# 12060      xrp  Dec 04, 2019     22.0     22.0     21.0     22.0
# 12061      xrp  Dec 03, 2019     22.0     22.0     22.0     22.0
# 12062      xrp  Dec 02, 2019     23.0     23.0     22.0     22.0
# 12063      xrp  Dec 01, 2019     23.0     23.0     22.0     23.0
# 12064      xrp  Nov 30, 2019     23.0     23.0     22.0     23.0
# ...        ...           ...      ...      ...      ...      ...
# 14467      xrp  May 02, 2013  11638.0  12560.0   9228.0  10521.0
# 14468      xrp  May 01, 2013  13900.0  13989.0  10772.0  11699.0
# 14469      xrp  Apr 30, 2013  14400.0  14693.0  13405.0  13900.0
# 14470      xrp  Apr 29, 2013  13444.0  14749.0  13400.0  14454.0
# 14471      xrp  Apr 28, 2013  13530.0  13598.0  13210.0  13421.0
#
#                 Volume       Market Cap
# 12060   1,427,312,577    9,364,745,688
# 12061   1,017,648,495    9,517,202,026
# 12062   1,187,513,777    9,507,818,760
# ...

# %%
import numpy as np
xrp['difference between open and close'] = xrp['Open'] - xrp['Close']
xrp.head()
# Out:
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_14792/1682768258.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xrp['difference between open and close'] = xrp['Open'] - xrp['Close']
#       Currency          Date  Open  High   Low  Close           Volume  \
# 12060      xrp  Dec 04, 2019  22.0  22.0  21.0   22.0   1,427,312,577
# 12061      xrp  Dec 03, 2019  22.0  22.0  22.0   22.0   1,017,648,495
# 12062      xrp  Dec 02, 2019  23.0  23.0  22.0   22.0   1,187,513,777
# 12063      xrp  Dec 01, 2019  23.0  23.0  22.0   23.0   1,176,237,060
# 12064      xrp  Nov 30, 2019  23.0  23.0  22.0   23.0   1,160,032,624
#
#             Market Cap  difference between open and close
# ...

# %%
xrp['percentage change'] = xrp['difference between open and close'] / xrp['Close']
xrp.head()
# Out:
# C:\Users\CHRIST~1.MUR\AppData\Local\Temp/ipykernel_14792/4104058727.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xrp['percentage change'] = xrp['difference between open and close'] / xrp['Close']
#       Currency          Date  Open  High   Low  Close           Volume  \
# 12060      xrp  Dec 04, 2019  22.0  22.0  21.0   22.0   1,427,312,577
# 12061      xrp  Dec 03, 2019  22.0  22.0  22.0   22.0   1,017,648,495
# 12062      xrp  Dec 02, 2019  23.0  23.0  22.0   22.0   1,187,513,777
# 12063      xrp  Dec 01, 2019  23.0  23.0  22.0   23.0   1,176,237,060
# 12064      xrp  Nov 30, 2019  23.0  23.0  22.0   23.0   1,160,032,624
#
#             Market Cap  difference between open and close  percentage change
# ...

# %%
sorted_coin_xrp = xrp.sort_values(by=['difference between open and close'], ascending=False)
print(sorted_coin_xrp.head(5))
# Out:
#       Currency          Date     Open     High      Low    Close Volume  \
# 14468      xrp  May 01, 2013  13900.0  13989.0  10772.0  11699.0   -
# 14405      xrp  Jul 03, 2013   9040.0   9098.0   7698.0   7753.0   -
# 14403      xrp  Jul 05, 2013   7999.0   8000.0   6553.0   6843.0   -
# 14467      xrp  May 02, 2013  11638.0  12560.0   9228.0  10521.0   -
# 14407      xrp  Jul 01, 2013   9751.0   9766.0   8630.0   8805.0   -
#
#             Market Cap  difference between open and close  percentage change
# 14468   1,298,954,594                              2201.0           0.188136
# 14405     881,233,116                              1287.0           0.166000
# 14403     778,411,179                              1156.0           0.168932
# 14467   1,168,517,495                              1117.0           0.106169
# 14407   1,000,065,296                               946.0           0.107439

# %%
sorted_coin_xrp = xrp.sort_values(by=['High'], ascending=False)
print(sorted_coin_xrp.head(5))
# Out:
#       Currency          Date     Open     High      Low    Close Volume  \
# 14470      xrp  Apr 29, 2013  13444.0  14749.0  13400.0  14454.0   -
# 14469      xrp  Apr 30, 2013  14400.0  14693.0  13405.0  13900.0   -
# 14468      xrp  May 01, 2013  13900.0  13989.0  10772.0  11699.0   -
# 14443      xrp  May 26, 2013  13199.0  13600.0  13062.0  13348.0   -
# 14471      xrp  Apr 28, 2013  13530.0  13598.0  13210.0  13421.0   -
#
#             Market Cap  difference between open and close  percentage change
# 14470   1,603,768,865                             -1010.0          -0.069877
# 14469   1,542,813,125                               500.0           0.035971
# 14468   1,298,954,594                              2201.0           0.188136
# 14443   1,495,293,015                              -149.0          -0.011163
# 14471   1,488,566,728                               109.0           0.008122

# %% [markdown]
# # API information

# %%
pip install pycoingecko
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import time
plt.style.use('seaborn')

# %%
cc = requests.get('https://api.coingecko.com/api/v3/simple/price?ids=bitcoin&vs_currencies=usd')
cc.json()
# Out:
# {'bitcoin': {'usd': 29205}}

# %%
cc = requests.get('https://api.coingecko.com/api/v3/coins/markets?vs_currency=USD')
cc.json()
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 29245,
#   'market_cap': 559249687945,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 616570969782,
#   'total_volume': 23935688891,
#   'high_24h': 30625,
#   'low_24h': 29297,
#   'price_change_24h': -779.3620919018103,
#   'price_change_percentage_24h': -2.59578,
#   'market_cap_change_24h': -12726670374.927612,
#   'market_cap_change_percentage_24h': -2.22503,
#   'circulating_supply': 19047675.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 69045,
#   'ath_change_percentage': -57.47611,
#   'ath_date': '2021-11-10T14:24:11.849Z',
#   'atl': 67.81,
#   'atl_change_percentage': 43198.85763,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2022-05-23T19:48:49.107Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
# ...

# %%
cc = requests.get('https://api.coingecko.com/api/v3/exchanges')
cc.json()
# Out:
# [{'id': 'binance',
#   'name': 'Binance',
#   'year_established': 2017,
#   'country': 'Cayman Islands',
#   'description': '',
#   'url': 'https://www.binance.com/',
#   'image': 'https://assets.coingecko.com/markets/images/52/small/binance.jpg?1519353250',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 1,
#   'trade_volume_24h_btc': 515255.37711950426,
#   'trade_volume_24h_btc_normalized': 515255.37711950426},
#  {'id': 'ftx_spot',
#   'name': 'FTX',
#   'year_established': 2019,
#   'country': 'Antigua and Barbuda',
#   'description': '',
#   'url': 'https://ftx.com/',
#   'image': 'https://assets.coingecko.com/markets/images/451/small/F.png?1609051590',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 2,
#   'trade_volume_24h_btc': 72020.10901474729,
#   'trade_volume_24h_btc_normalized': 72020.10901474729},
#  {'id': 'gdax',
#   'name': 'Coinbase Exchange',
#   'year_established': 2012,
# ...

# %%
cc = requests.get('https://api.coingecko.com/api/v3/global')
cc.json()
# Out:
# {'data': {'active_cryptocurrencies': 13415,
#   'upcoming_icos': 0,
#   'ongoing_icos': 49,
#   'ended_icos': 3376,
#   'markets': 808,
#   'total_market_cap': {'btc': 45248418.43628694,
#    'eth': 665595256.6895391,
#    'ltc': 18770270255.363605,
#    'bch': 6804832147.749963,
#    'bnb': 4074495570.767024,
#    'eos': 984041626179.6979,
#    'xrp': 3221212254630.896,
#    'xlm': 10062104553621.959,
#    'link': 182841766663.8502,
#    'dot': 128911838143.90746,
#    'yfi': 143070938.46982738,
#    'usd': 1322616507191.2761,
#    'aed': 4858102692564.251,
#    'ars': 157314185714717.56,
#    'aud': 1862369690693.4988,
#    'bdt': 116334446151927.55,
#    'bhd': 498633036293.64514,
#    'bmd': 1322616507191.2761,
#    'brl': 6358082073369.906,
#    'cad': 1690122697728.9622,
#    'chf': 1277810227777.1555,
#    'clp': 1098565270873072.2,
#    'cny': 8796325604376.998,
#    'czk': 30486707275711.05,
#    'dkk': 9207003320325.947,
#    'eur': 1237446617210.6934,
# ...

# %% [markdown]
# # Future trends

# %%
import seaborn as sns

# %%
import pandas as pd
coin = pd.read_csv(r'C:\Users\Christine.Murphy\OneDrive - Concern Worldwide\2022\UCD_Course\consolidated_coin_data2.csv')

# %%
sns.pairplot(coin)
plt.title('Crypto currencies - future trends')
# Out:
# Text(0.5, 1.0, 'Crypto currencies - future trends')
